# %% [markdown]
# ## Imports necesarios

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# # Mini ejemplo homografía entre dos imágenes
# 1) Marcar los mismos seis puntos y en el mismo orden en ambas imágenes
# 2) Se genera un mapa esquemático de la cancha de voley playa y las personas presentes

# %%
# 0. FUNCIONES

def get_screen_size():
    screen = np.zeros((1, 1, 3), dtype=np.uint8)
    cv2.namedWindow("_tmp", cv2.WINDOW_NORMAL)
    cv2.imshow("_tmp", screen)
    cv2.waitKey(1)
    _, _, w, h = cv2.getWindowImageRect("_tmp")
    cv2.destroyWindow("_tmp")
    return w, h

def resize_to_screen(img, screen_w, screen_h, margin=100):
    h, w = img.shape[:2]
    scale = min((screen_w - margin) / w, (screen_h - margin) / h, 1.0)
    return cv2.resize(img, (int(w * scale), int(h * scale)))

def get_points(event, x, y, flags, params):
    points = params["points"]
    image = params["image"]
    wname = params["wname"]
    max_points = params["max_points"]

    if event == cv2.EVENT_LBUTTONDOWN and len(points) < max_points:
        points.append([x, y])
        cv2.circle(image, (x, y), 6, (0, 0, 255), -1)
        cv2.putText(image, str(len(points)), (x + 5, y - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
        cv2.imshow(wname, image)

        if len(points) == max_points:
            cv2.waitKey(300)
            cv2.destroyWindow(wname)

def resize_by_width(img, target_width):
    h, w = img.shape[:2]
    scale = target_width / w
    return cv2.resize(img, (target_width, int(h * scale)))

# 1. CARGAR VIDEO Y MAPA
video = cv2.VideoCapture("VideosAnalisis\clip 1 ‐ Hecho con Clipchamp.mp4")
mapa = cv2.imread("beachvolleyballcourt.png")

ret, first_frame = video.read()
if not ret:
    raise RuntimeError("No se pudo leer el video")
if mapa is None:
    raise FileNotFoundError("No se pudo cargar el mapa.")

# 2. SELECCIÓN DE PUNTOS
screen_w, screen_h = get_screen_size()
puntosA, puntosB = [], []
N = 6

# puntos en el primer frame
imgA = first_frame.copy()
cv2.namedWindow("Vista", cv2.WINDOW_NORMAL)
cv2.resizeWindow("Vista", 1200, 800)
cv2.imshow("Vista", imgA)
cv2.setMouseCallback("Vista", get_points,
                     {"points": puntosA, "image": imgA, "wname": "Vista", "max_points": N})
cv2.waitKey(0)

# puntos en el mapa
imgB = mapa.copy()
cv2.namedWindow("Mapa", cv2.WINDOW_NORMAL)
cv2.resizeWindow("Mapa", 1200, 800)
cv2.imshow("Mapa", imgB)
cv2.setMouseCallback("Mapa", get_points,
                     {"points": puntosB, "image": imgB, "wname": "Mapa", "max_points": N})
cv2.waitKey(0)
cv2.destroyAllWindows()

pA = np.array(puntosA, dtype=np.float32)
pB = np.array(puntosB, dtype=np.float32)

# 3. HOMOGRAFÍA
H, _ = cv2.findHomography(pA, pB)

# 4. MODELO YOLO
model = YOLO("yolo11n.pt")

# 5. LOOP PRINCIPAL
TARGET_VIDEO_WIDTH = 800
MINIMAP_HEIGHT_RATIO = 0.5

while True:
    ret, frame = video.read()
    if not ret:
        video.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    # detecta y trackea personas
    results = model.track(frame, persist=True, verbose=False)
    person_pixels = []

    for r in results:
        if r.boxes.id is None:
            continue
        for box, track_id in zip(r.boxes, r.boxes.id):
            if int(box.cls[0]) == 0:  # persona
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                px = (x1 + x2) // 2
                py = y2
                person_pixels.append([px, py, int(track_id)])

                cv2.circle(frame, (px, py), 6, (0, 255, 0), -1)
                cv2.putText(frame, f"ID {int(track_id)}", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # dibuja los jugadores en el minimapa
    mapa_out = mapa.copy()
    if person_pixels:
        pts = np.array([[p[0], p[1]] for p in person_pixels], dtype=np.float32).reshape(-1, 1, 2)
        players_mapa = cv2.perspectiveTransform(pts, H)

        for (x, y), (_, _, track_id) in zip(players_mapa.reshape(-1, 2), person_pixels):
            x, y = int(x), int(y)
            cv2.circle(mapa_out, (x, y), 10, (0, 0, 255), -1)
            cv2.putText(mapa_out, f"{track_id}", (x + 8, y - 8),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # combina video y minimapa
    frame_h, frame_w = frame.shape[:2]
    frame_r = cv2.resize(frame, (TARGET_VIDEO_WIDTH, int(frame_h * TARGET_VIDEO_WIDTH / frame_w)))
    target_h = frame_r.shape[0]

    minimap_target_h = int(target_h * MINIMAP_HEIGHT_RATIO)
    mapa_r = cv2.resize(mapa_out, (int(mapa_out.shape[1] * minimap_target_h / mapa_out.shape[0]), minimap_target_h))

    padding_top = (target_h - minimap_target_h) // 2
    padding_bottom = target_h - minimap_target_h - padding_top
    mapa_padded = cv2.copyMakeBorder(mapa_r, padding_top, padding_bottom, 0, 0, cv2.BORDER_CONSTANT, value=[0, 0, 0])

    try:
        combined = np.hstack((frame_r, mapa_padded))
    except ValueError as e:
        print(f"Error al combinar: {e}")
        break

    cv2.imshow("Video + Minimapa (Tracking)", combined)

    if cv2.waitKey(30) & 0xFF == 27:
        break

video.release()
cv2.destroyAllWindows()

# %%
# ============================================
# 0. FUNCIONES
# ============================================
import cv2
import numpy as np
from ultralytics import YOLO # Asegúrate de que esta línea esté al inicio si no lo estaba

def get_screen_size():
    screen = np.zeros((1, 1, 3), dtype=np.uint8)
    cv2.namedWindow("_tmp", cv2.WINDOW_NORMAL)
    cv2.imshow("_tmp", screen)
    cv2.waitKey(1)

    _, _, w, h = cv2.getWindowImageRect("_tmp")
    cv2.destroyWindow("_tmp")

    return w, h

def resize_to_screen(img, screen_w, screen_h, margin=100):
    h, w = img.shape[:2]

    max_w = screen_w - margin
    max_h = screen_h - margin

    scale = min(max_w / w, max_h / h, 1.0)

    new_w = int(w * scale)
    new_h = int(h * scale)

    return cv2.resize(img, (new_w, new_h))


def get_points(event, x, y, flags, params):
    points = params["points"]
    image = params["image"]
    wname = params["wname"]
    max_points = params["max_points"]

    if event == cv2.EVENT_LBUTTONDOWN and len(points) < max_points:
        points.append([x, y])

        cv2.circle(image, (x, y), 6, (0, 0, 255), -1)
        cv2.putText(
            image,
            str(len(points)),
            (x + 5, y - 5),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.6,
            (255, 0, 0),
            2
        )

        cv2.imshow(wname, image)

        if len(points) == max_points:
            cv2.waitKey(300)
            cv2.destroyWindow(wname)


def resize_by_width(img, target_width):
    h, w = img.shape[:2]
    # Se ajusta el factor de escala para mantener la proporción de la altura
    scale = target_width / w
    return cv2.resize(img, (target_width, int(h * scale)))


# ============================================
# 1. CARGAR VIDEO Y MAPA
# ============================================

video = cv2.VideoCapture("VideosAnalisis\clip 1 ‐ Hecho con Clipchamp.mp4")
mapa = cv2.imread("beachvolleyballcourt.png")

ret, first_frame = video.read()
if not ret:
    raise RuntimeError("No se pudo leer el video")

# VERIFICACIÓN:
if mapa is None:
    raise FileNotFoundError("ERROR: No se pudo cargar 'beachvolleyballcourt.png'. Verifique la ruta.")


# ============================================
# 2. SELECCIÓN DE PUNTOS (UNA SOLA VEZ)
# ... (El código de selección de puntos es el mismo) ...
# ============================================
screen_w, screen_h = get_screen_size()
puntosA, puntosB = [], []
N = 6

# Antes de mostrar Vista
imgA = first_frame.copy()
cv2.namedWindow("Vista", cv2.WINDOW_NORMAL) 
cv2.resizeWindow("Vista", 1200, 800) 
cv2.imshow("Vista", imgA)

cv2.setMouseCallback(
    "Vista", get_points,
    {"points": puntosA, "image": imgA, "wname": "Vista", "max_points": N}
)
cv2.waitKey(0)

imgB = mapa.copy()
cv2.namedWindow("Mapa", cv2.WINDOW_NORMAL) 
cv2.resizeWindow("Mapa", 1200, 800) 
cv2.imshow("Mapa", imgB)

cv2.setMouseCallback(
    "Mapa", get_points,
    {"points": puntosB, "image": imgB, "wname": "Mapa", "max_points": N}
)
cv2.waitKey(0)
cv2.destroyAllWindows()

pA = np.array(puntosA, dtype=np.float32)
pB = np.array(puntosB, dtype=np.float32)

# ============================================
# 3. HOMOGRAFÍA
# ============================================

H, _ = cv2.findHomography(pA, pB)

# ============================================
# 4. MODELO YOLO
# ============================================

model = YOLO("yolo11n.pt")

# ============================================
# 5. LOOP INFINITO (VIDEO TIPO GIF)
# ============================================

# --- NUEVOS PARÁMETROS DE VISUALIZACIÓN ---
TARGET_VIDEO_WIDTH = 800  # Ancho deseado para el video (ajustable)
MINIMAP_HEIGHT_RATIO = 0.5 # Altura del minimapa será la mitad de la altura del video

while True:

    ret, frame = video.read()

    # 🔁 repetir vídeo como GIF
    if not ret:
        video.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    # ----------------------------------------
    # DETECCIÓN DE PERSONAS (Mismo código)
    # ----------------------------------------
    results = model(frame, verbose=False)
    person_pixels = []

    for r in results:
        for box in r.boxes:
            if int(box.cls[0]) == 0:  # 0 = 'person' en COCO
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                px = (x1 + x2) // 2
                py = y2
                person_pixels.append([px, py])
                cv2.circle(frame, (px, py), 6, (0, 255, 0), -1)

    # ----------------------------------------
    # MAPA ANIMADO (Mismo código)
    # ----------------------------------------
    mapa_out = mapa.copy()

    if person_pixels:
        pts = np.array(person_pixels, dtype=np.float32).reshape(-1, 1, 2)
        players_mapa = cv2.perspectiveTransform(pts, H)

        for p in players_mapa:
            x, y = map(int, p[0])
            cv2.circle(mapa_out, (x, y), 10, (0, 0, 255), -1)

    # ----------------------------------------
    # 🔴 COMBINAR LADO A LADO (Lógica de redimensionamiento corregida)
    # ----------------------------------------
    
    # 1. Redimensionar el Frame del Video al ancho objetivo
    frame_h, frame_w = frame.shape[:2]
    video_scale = TARGET_VIDEO_WIDTH / frame_w
    frame_r = cv2.resize(frame, (TARGET_VIDEO_WIDTH, int(frame_h * video_scale)))
    
    # Altura de referencia para la apilación
    target_h = frame_r.shape[0]

    # 2. Redimensionar el Minimapa para que su altura sea una fracción del video
    minimap_target_h = int(target_h * MINIMAP_HEIGHT_RATIO)
    mapa_h, mapa_w = mapa_out.shape[:2]
    
    # Calcular el nuevo ancho del minimapa manteniendo su proporción
    minimap_target_w = int(mapa_w * (minimap_target_h / mapa_h))
    mapa_r = cv2.resize(mapa_out, (minimap_target_w, minimap_target_h))
    
    # 3. Padding (Relleno) para igualar la altura antes de hstack
    # Creamos un fondo negro del mismo alto que el video (target_h)
    # y del mismo ancho que el minimapa (minimap_target_w).
    padding_top = (target_h - minimap_target_h) // 2
    padding_bottom = target_h - minimap_target_h - padding_top
    
    mapa_padded = cv2.copyMakeBorder(
        mapa_r, 
        padding_top, 
        padding_bottom, 
        0, 
        0, 
        cv2.BORDER_CONSTANT, 
        value=[0, 0, 0] # Color negro
    )
    
    # 4. Concatenar horizontalmente (lado a lado)
    try:
        combined = np.hstack((frame_r, mapa_padded)) 
    except ValueError as e:
        print(f"Error de concatenación: Asegúrese que todas las imágenes sean BGR (3 canales). {e}")
        break

    # 5. Mostrar el resultado
    cv2.imshow("Video + Minimapa (Resultado Final)", combined)

    # ESC para salir
    if cv2.waitKey(30) & 0xFF == 27:
        break

video.release()
cv2.destroyAllWindows()
