# %% [markdown]
# ## Imports necesarios

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import os
import pandas as pd

# %% [markdown]
# # Mini ejemplo homografía entre dos imágenes
# 1) Marcar los mismos seis puntos y en el mismo orden en ambas imágenes
# 2) Se genera un mapa esquemático de la cancha de voley playa y las personas presentes

# %%
def get_screen_size():
    screen = np.zeros((1, 1, 3), dtype=np.uint8)
    cv2.namedWindow("_tmp", cv2.WINDOW_NORMAL)
    cv2.imshow("_tmp", screen)
    cv2.waitKey(1)
    _, _, w, h = cv2.getWindowImageRect("_tmp")
    cv2.destroyWindow("_tmp")
    return w, h

def resize_by_width(img, target_width):
    h, w = img.shape[:2]
    scale = target_width / w
    return cv2.resize(img, (target_width, int(h * scale)))

def get_points(event, x, y, flags, params):
    points = params["points"]
    image = params["image"]
    wname = params["wname"]
    max_points = params["max_points"]
    if event == cv2.EVENT_LBUTTONDOWN and len(points) < max_points:
        points.append([x, y])
        cv2.circle(image, (x, y), 6, (0, 0, 255), -1)
        cv2.putText(image, str(len(points)), (x + 5, y - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
        cv2.imshow(wname, image)
        if len(points) == max_points:
            cv2.waitKey(300)
            cv2.destroyWindow(wname)

# %%
# -------- Cargar video y mapa --------
video_path = "VideosAnalisis\clip 1 ‐ Hecho con Clipchamp.mp4"
mapa_path = "beachvolleyballcourt.png"
video = cv2.VideoCapture(video_path)
mapa = cv2.imread(mapa_path)
ret, first_frame = video.read()
if not ret:
    raise RuntimeError("No se pudo leer el video")
if mapa is None:
    raise FileNotFoundError("No se pudo cargar el mapa.")

# -------- Selección de puntos para homografía --------
screen_w, screen_h = get_screen_size()
puntosA, puntosB = [], []
N = 6

# Primer frame
imgA = first_frame.copy()
cv2.namedWindow("Vista", cv2.WINDOW_NORMAL)
cv2.resizeWindow("Vista", 1200, 800)
cv2.imshow("Vista", imgA)
cv2.setMouseCallback("Vista", get_points,
                     {"points": puntosA, "image": imgA, "wname": "Vista", "max_points": N})
cv2.waitKey(0)

# Mapa
imgB = mapa.copy()
cv2.namedWindow("Mapa", cv2.WINDOW_NORMAL)
cv2.resizeWindow("Mapa", 1200, 800)
cv2.imshow("Mapa", imgB)
cv2.setMouseCallback("Mapa", get_points,
                     {"points": puntosB, "image": imgB, "wname": "Mapa", "max_points": N})
cv2.waitKey(0)
cv2.destroyAllWindows()

# Cálculo de homografía
pA = np.array(puntosA, dtype=np.float32)
pB = np.array(puntosB, dtype=np.float32)
H, _ = cv2.findHomography(pA, pB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 39
#      37 pA = np.array(puntosA, dtype=np.float32)
#      38 pB = np.array(puntosB, dtype=np.float32)
# ---> 39 H, _ = cv2.findHomography(pA, pB)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:390: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'

# %%
# -------- Inicializar YOLO --------
model = YOLO("yolo11n.pt")
frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

detections = []

for f_idx in range(frame_count):
    ret, frame = video.read()
    if not ret:
        break

    results = model.track(frame, imgsz=960, persist=True, verbose=False)

    for r in results:
        if r.boxes.id is None:
            continue
        for box, track_id in zip(r.boxes, r.boxes.id):
            cls = int(box.cls[0])
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            px = (x1 + x2) // 2
            py = y2

            detections.append({
                "frame": f_idx,
                "track_id": int(track_id),
                "class": cls,
                "x": px,
                "y": py,
                "x1": x1,
                "y1": y1,
                "x2": x2,
                "y2": y2
            })

# Guardar en CSV
csv_name = os.path.splitext(os.path.basename(video_path))[0] + ".csv"
df = pd.DataFrame(detections)
df.to_csv(csv_name, index=False)
print(f"Detecciones guardadas en {csv_name}")

video.release()
# Out:
# Detecciones guardadas en clip 1 ‐ Hecho con Clipchamp.csv

# %%
# -------- Reproducir vídeo con detecciones --------
video = cv2.VideoCapture(video_path)
df = pd.read_csv(csv_name)
TARGET_VIDEO_WIDTH = 800
MINIMAP_HEIGHT_RATIO = 0.5

while True:
    ret, frame = video.read()
    if not ret:
        break
    f_idx = int(video.get(cv2.CAP_PROP_POS_FRAMES)) - 1
    frame_dets = df[df["frame"] == f_idx]

    # Dibujar detecciones
    mapa_out = mapa.copy()
    for _, det in frame_dets.iterrows():
        px, py = int(det["x"]), int(det["y"])
        cls = int(det["class"])
        track_id = int(det["track_id"])

        color = (0, 0, 0) if cls == 0 else(255, 255, 255)  # rojo personas, blanco pelota
        cv2.circle(frame, (px, py), 6, color, -1)
        label = f"ID {track_id}" if cls == 0 else "Pelota"
        cv2.putText(frame, label, (px + 5, py - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        # proyectar al minimapa
        pt = np.array([[px, py]], dtype=np.float32).reshape(-1, 1, 2)
        x_map, y_map = cv2.perspectiveTransform(pt, H).reshape(-1, 2)[0]
        x_map, y_map = int(x_map), int(y_map)
        cv2.circle(mapa_out, (x_map, y_map), 24, color, -1)
        cv2.putText(mapa_out, label, (x_map + 5, y_map - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # Combinar frame y minimapa
    frame_h, frame_w = frame.shape[:2]
    frame_r = cv2.resize(frame, (TARGET_VIDEO_WIDTH, int(frame_h * TARGET_VIDEO_WIDTH / frame_w)))
    target_h = frame_r.shape[0]

    minimap_target_h = int(target_h * MINIMAP_HEIGHT_RATIO)
    mapa_r = cv2.resize(mapa_out, (int(mapa_out.shape[1] * minimap_target_h / mapa_out.shape[0]), minimap_target_h))
    padding_top = (target_h - minimap_target_h) // 2
    padding_bottom = target_h - minimap_target_h - padding_top
    mapa_padded = cv2.copyMakeBorder(mapa_r, padding_top, padding_bottom, 0, 0,
                                     cv2.BORDER_CONSTANT, value=[0, 0, 0])

    combined = np.hstack((frame_r, mapa_padded))
    cv2.imshow("Video + Minimapa (Tracking)", combined)

    if cv2.waitKey(30) & 0xFF == 27:
        break

video.release()
cv2.destroyAllWindows()
